# %% [markdown]
# # Plotting Q husimi functions
# Plotting Q husimi functions for different quantum states

# %%
using PyPlot

using3D() # Needed to create a 3D subplot

###################
##  Create Data  ##
###################
n = 100
x = range(-3,stop=3,length=n)
y = range(-3,stop=3,length=n)

xgrid = repeat(x',n,1)
ygrid = repeat(y,1,n)
a1 = pi/sqrt(2)
a2 = pi/sqrt(2)
z = zeros(n,n)

for i in 1:n
    for j in 1:n
        z[i:i,j:j] .= abs2.(((cos.((x[i]+1im*y[j])/2)).^2).*exp.(-abs2.(x[i]+1im*y[j])) .+ cos.((x[i]+1im*y[j])/2).*sin.((x[i]+1im*y[j])/2).*exp.(-abs2.(x[i]+1im*y[j])).*exp.(1im.*a2).*((x[i]+1im*y[j]).^12)/(sqrt(factorial(12)))) 
    end
end

############
##  Plot  ##
############
fig = figure("pyplot_surfaceplot",figsize=(8,8))
ax = fig.add_subplot(2,1,1,projection="3d")
plot_surface(xgrid, ygrid, z, rstride=2,edgecolors="k", cstride=2, cmap=ColorMap("rainbow"), alpha=0.8, linewidth=0.25)
xlabel("X")
ylabel("Y")
PyPlot.title("Surface Plot")

subplot(212)
ax = fig.add_subplot(2,1,2)
cp = contour(xgrid, ygrid, z, colors="black", linewidth=2.0)
ax.clabel(cp, inline=1, fontsize=10)
xlabel("X")
ylabel("Y")
PyPlot.title("Contour Plot")
tight_layout()
# Out:
# Figure(PyObject <Figure size 800x800 with 2 Axes>)

# %%
pcolor(x,y,z)
tight_layout
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# tight_layout (generic function with 1 method)

# %%
using PyPlot

using3D() # Needed to create a 3D subplot

###################
##  Create Data  ##
###################
n = 100
x = range(-3,stop=3,length=n)
y = range(-3,stop=3,length=n)

xgrid = repeat(x',n,1)
ygrid = repeat(y,1,n)
a1 = pi/sqrt(2)
a2 = pi/sqrt(2)
z = zeros(n,n)

for i in 1:n
    for j in 1:n
        z[i:i,j:j] .= log(10,abs2.(1 .+ exp.(-2*abs2.(x[i] .+ 1im*y[j]))*1/sqrt(2)))
    end
end

############
##  Plot  ##
############
fig = figure("pyplot_surfaceplot",figsize=(8,8))
ax = fig.add_subplot(2,1,1,projection="3d")
plot_surface(xgrid, ygrid, z, rstride=2,edgecolors="k", cstride=2, cmap=ColorMap("rainbow"), alpha=0.8, linewidth=0.25)
xlabel("X")
ylabel("Y")
PyPlot.title("Surface Plot")

subplot(212)
ax = fig.add_subplot(2,1,2)
cp = contour(xgrid, ygrid, z, colors="black", linewidth=2.0)
ax.clabel(cp, inline=1, fontsize=10)
xlabel("X")
ylabel("Y")
PyPlot.title("Contour Plot")
tight_layout()
# Out:
# Figure(PyObject <Figure size 800x800 with 2 Axes>)

# %%
pcolor(x,y,z)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PolyCollection object at 0x00000000464300F0>

# %%
using PyPlot

using3D() # Needed to create a 3D subplot

###################
##  Create Data  ##
###################
n = 100
x = range(-3,stop=3,length=n)
y = range(-3,stop=3,length=n)

xgrid = repeat(x',n,1)
ygrid = repeat(y,1,n)
a1 = pi/sqrt(2)
a2 = pi/sqrt(2)
z = zeros(n,n)
N = 10
phi = pi/4

for i in 1:n
    for j in 1:n
        z[i:i,j:j] .= abs2.(1/sqrt(N)*sum((exp.(-1im*k*phi))*(exp(-abs2.(x[i] + 1im*y[j])/2))*((x[i] + 1im*y[j])^k)/sqrt(factorial(k)) for k in 1:N)) 
    end
end

############
##  Plot  ##
############
fig = figure("pyplot_surfaceplot",figsize=(8,8))
ax = fig.add_subplot(2,1,1,projection="3d")
plot_surface(xgrid, ygrid, z, rstride=2,edgecolors="k", cstride=2, cmap=ColorMap("rainbow"), alpha=0.8, linewidth=0.25)
xlabel("X")
ylabel("Y")
PyPlot.title("Surface Plot")

subplot(212)
ax = fig.add_subplot(2,1,2)
cp = contour(xgrid, ygrid, z, colors="black", linewidth=2.0)
ax.clabel(cp, inline=1, fontsize=10)
xlabel("X")
ylabel("Y")
PyPlot.title("Contour Plot")
tight_layout()
# Out:
# Figure(PyObject <Figure size 800x800 with 2 Axes>)

# %%
pcolor(x,y,z)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PolyCollection object at 0x000000004A913BE0>

# %%
using PyPlot

using3D() # Needed to create a 3D subplot

###################
##  Create Data  ##
###################
n = 100
x = range(-3,stop=3,length=n)
y = range(-3,stop=3,length=n)

xgrid = repeat(x',n,1)
ygrid = repeat(y,1,n)
a1 = pi/sqrt(2)
a2 = pi/sqrt(2)
z = zeros(n,n)
N = 10
phi = pi/4
eps = 1.2
for i in 1:n
    for j in 1:n
        z[i:i,j:j] .= abs2.((1/(cosh(eps)))exp(-abs2.(x[i] + 1im*y[j])/2 + (((x[i] + 1im*y[j])^2)/2)*tanh(eps)  )) 
    end
end

############
##  Plot  ##
############
fig = figure("pyplot_surfaceplot",figsize=(8,8))
ax = fig.add_subplot(2,1,1,projection="3d")
plot_surface(xgrid, ygrid, z, rstride=2,edgecolors="k", cstride=2, cmap=ColorMap("rainbow"), alpha=0.8, linewidth=0.25)
xlabel("X")
ylabel("Y")
PyPlot.title("Surface Plot")

subplot(212)
ax = fig.add_subplot(2,1,2)
cp = contour(xgrid, ygrid, z, colors="black", linewidth=2.0)
ax.clabel(cp, inline=1, fontsize=10)
xlabel("X")
ylabel("Y")
PyPlot.title("Contour Plot")
tight_layout()
# Out:
# Figure(PyObject <Figure size 800x800 with 2 Axes>)

# %%
pcolor(x,y,z)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PolyCollection object at 0x0000000047D4DE80>
